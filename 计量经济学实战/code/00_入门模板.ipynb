# %% [markdown]
# # 计量经济学实战 · 入门模板
#
# - 本 notebook 在 Jupyter Lab 中手工运行。
# - 下方为常用库导入；后续单元格可在此项目下做回归、检验、作图等，需要写代码时可让 AI 辅助生成或修改。

# %%
# 常用库（按需增删）
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import statsmodels.formula.api as smf
# from wooldridge import load_data  # Wooldridge 教材数据

pd.set_option('display.max_columns', 20)
# %matplotlib inline

# %% [markdown]
# ## 你的分析
#
# 在下方新增单元格，加载数据、做回归或画图。需要写脚本时可在 Cursor 中描述需求，把生成的代码粘贴到这里运行。

# %%
# 示例：加载数据（路径按你的 data/ 或其它位置修改）
# df = pd.read_csv('../data/xxx.csv')
# df.info()
