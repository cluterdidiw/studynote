# %%
datas = pd.read_csv('/Users/didiw/Documents/study/studynote/计量经济学导论学习/data/OLS_test.csv') #

# %%
datas
# Out:
#     不良贷款  各项贷款余额  本年累计应收贷款  贷款项目个数  本年固定资产投资额
# 0    0.9    67.3       6.8       5       51.9
# 1    1.1   111.3      19.8      16       90.9
# 2    4.8   173.0       7.7      17       73.7
# 3    3.2    80.8       7.2      10       14.5
# 4    7.8   199.7      16.5      19       63.2
# 5    2.7    16.2       2.2       1        2.2
# 6    1.6   107.4      10.7      17       20.2
# 7   12.5   185.4      27.1      18       43.8
# 8    1.0    96.1       1.7      10       55.9
# 9    2.6    72.8       9.1      14       64.3
# 10   0.3    64.2       2.1      11       42.7
# 11   4.0   132.2      11.2      23       76.7
# 12   0.8    58.6       6.0      14       22.8
# 13   3.5   174.6      12.7      26      117.1
# 14  10.2   263.5      15.6      34      146.7
# 15   3.0    79.3       8.9      15       29.9
# 16   0.2    14.8       0.6       2       42.1
# 17   0.4    73.5       5.9      11       25.3
# 18   1.0    24.7       5.0       4       13.4
# ...

# %%
y = datas.iloc[:, 0] # 因变量为第 2 列数据
x = datas.iloc[:, 1] # 自变量为第 3 列数据

# %% [markdown]
# ## scipy

# %%
import scipy.stats as st
import pandas as pd

# 线性拟合，可以返回斜率，截距，r 值，p 值，标准误差
slope, intercept, r_value, p_value, std_err = st.linregress(x, y)

print(slope)# 输出斜率
print(intercept) # 输出截距
print(r_value**2) # 输出 r^2
# Out:
# 0.03789470695901016
# -0.8295206165462337
# 0.7116126467669922

# %% [markdown]
# ## statsmodels

# %%
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
x = sm.add_constant(x) # 若模型中有截距，必须有这一步
model = sm.OLS(y, x).fit() # 构建最小二乘模型并拟合
print(model.summary()) # 输出回归结果

# 画图
# 这两行代码在画图时添加中文必须用
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

predicts = model.predict() # 模型的预测值
x = datas.iloc[:, 1] # 自变量为第 3 列数据
plt.scatter(x, y, label='实际值') # 散点图
plt.plot(x, predicts, color = 'red', label='预测值')
plt.legend() # 显示图例，即每条线对应 label 中的内容
plt.show() # 显示图形
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   不良贷款   R-squared:                       0.712
# Model:                            OLS   Adj. R-squared:                  0.699
# Method:                 Least Squares   F-statistic:                     56.75
# Date:                Tue, 04 Jan 2022   Prob (F-statistic):           1.18e-07
# Time:                        11:45:25   Log-Likelihood:                -51.508
# No. Observations:                  25   AIC:                             107.0
# Df Residuals:                      23   BIC:                             109.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.8295      0.723     -1.147      0.263      -2.325       0.666
# ...

# %%
import pandas as pd
import statsmodels.formula.api as sm
import matplotlib.pyplot as plt


model = sm.ols('不良贷款~各项贷款余额', datas).fit() # 构建最小二乘模型并拟合，
                               #此时不用单独输入 x，y了，而是将自变量与因变量用统计语言公式表示，将全部数据导入
print(model.summary()) # 输出回归结果


# 画图
# 这两行代码在画图时添加中文必须用
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

predicts = model.predict() # 模型的预测值
y = datas.iloc[:, 0] # 因变量为第 2 列数据
x = datas.iloc[:, 1] # 自变量为第 3 列数据
plt.scatter(x, y, label='实际值')
plt.plot(x, predicts, color = 'red', label='预测值')
plt.legend() # 显示图例，即每条线对应 label 中的内容
plt.show() # 显示图形
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   不良贷款   R-squared:                       0.712
# Model:                            OLS   Adj. R-squared:                  0.699
# Method:                 Least Squares   F-statistic:                     56.75
# Date:                Thu, 06 Jan 2022   Prob (F-statistic):           1.18e-07
# Time:                        10:46:50   Log-Likelihood:                -51.508
# No. Observations:                  25   AIC:                             107.0
# Df Residuals:                      23   BIC:                             109.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.8295      0.723     -1.147      0.263      -2.325       0.666
# ...

# %%
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
y = datas.iloc[:, 0] # 因变量为第 2 列数据
x = datas.iloc[:, 1:5] # 自变量为第 3 列到第 6 列数据
x = sm.add_constant(x) # 若模型中有截距，必须有这一步
model = sm.OLS(y, x).fit() # 构建最小二乘模型并拟合
print(model.summary()) # 输出回归结果
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   不良贷款   R-squared:                       0.798
# Model:                            OLS   Adj. R-squared:                  0.757
# Method:                 Least Squares   F-statistic:                     19.70
# Date:                Thu, 06 Jan 2022   Prob (F-statistic):           1.04e-06
# Time:                        11:01:01   Log-Likelihood:                -47.082
# No. Observations:                  25   AIC:                             104.2
# Df Residuals:                      20   BIC:                             110.3
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -1.0216      0.782     -1.306      0.206      -2.654       0.610
# ...

# %% [markdown]
# ## sklearn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression


y = datas.iloc[:, 0] # 因变量为第 2 列数据
x = datas.iloc[:, 1] # 自变量为第 3 列数据

# 将 x，y 分别增加一个轴，以满足 sklearn 中回归模型认可的数据
x = x[:, np.newaxis]
y = y[:, np.newaxis]

model = LinearRegression() # 构建线性模型
model.fit(x, y) # 自变量在前，因变量在后
predicts = model.predict(x) # 预测值
R2 = model.score(x, y) # 拟合程度 R2
print('R2 = %.2f' % R2) # 输出 R2
coef = model.coef_ # 斜率
intercept = model.intercept_ # 截距
print(model.coef_, model.intercept_) # 输出斜率和截距

# 画图
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

y = datas.iloc[:, 0] # 因变量为第 2 列数据
x = datas.iloc[:, 1] # 自变量为第 3 列数据
plt.scatter(x, y, label='实际值') # 散点图
plt.plot(x, predicts, color = 'red', label='预测值')
plt.legend() # 显示图例，即每条线对应 label 中的内容
plt.show() # 显示图形
# Out:
# <ipython-input-15-1cba2d010baf>:11: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# <ipython-input-15-1cba2d010baf>:12: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# /Users/didiw/anaconda3/envs/py3ana/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 39044 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/didiw/anaconda3/envs/py3ana/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 27979 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
# !pwd
# Out:
# /Users/didiw/Documents/study/studynote/计量经济学导论学习/code
