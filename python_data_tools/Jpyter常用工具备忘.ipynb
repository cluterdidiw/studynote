# %% [markdown]
# # Jupyter 常用工具备忘

# %% [markdown]
# ## 1.文件操作类

# %% [markdown]
# ### 1.1 列出指定文件夹中的所有文件路径及文件名

# %%
# 列出指定 文件夹中的所有文件路径及文件名
# '/Users/didiw/Documents/study/kaggle/project/EDAstudy/input'
def show_files(dirl):
    import os
    for dirname, _, filenames in os.walk(dirl):
        for filename in filenames:
            print(os.path.join(dirname, filename))

# %%
show_files('/Users/didiw/Documents/study/kaggle/project/EDAstudy/input')
# Out:
# /Users/didiw/Documents/study/kaggle/project/EDAstudy/input/station_day.csv
# /Users/didiw/Documents/study/kaggle/project/EDAstudy/input/city_hour.csv
# /Users/didiw/Documents/study/kaggle/project/EDAstudy/input/Indian Cities Database.csv
# /Users/didiw/Documents/study/kaggle/project/EDAstudy/input/city_day.csv
# /Users/didiw/Documents/study/kaggle/project/EDAstudy/input/stations.csv
# /Users/didiw/Documents/study/kaggle/project/EDAstudy/input/station_hour.csv

# %% [markdown]
# ## 2.配置类

# %% [markdown]
# ### 2.1 显示被压缩的数据

# %%
import pandas as pd
import numpy as np
# set up display area to show dataframe in jupyter qtconsole

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
df = pd.DataFrame(np.random.random(200).reshape(2, 100))
df
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.914797  0.650964  0.913160  0.007747  0.409363  0.836670  0.733897
# 1  0.143215  0.930491  0.851519  0.548017  0.306799  0.438065  0.449796
#
#          7         8         9         10        11        12        13  \
# 0  0.587421  0.050763  0.834158  0.743887  0.517106  0.211433  0.304195
# 1  0.299647  0.997095  0.604614  0.425545  0.024168  0.326225  0.195284
#
#          14        15        16        17        18        19        20  \
# 0  0.434939  0.015346  0.723711  0.188102  0.115646  0.886013  0.083108
# 1  0.594036  0.620376  0.242346  0.084108  0.032308  0.641217  0.451103
#
#          21        22        23        24        25        26        27  \
# 0  0.174355  0.593411  0.913325  0.771220  0.504238  0.085043  0.125235
# 1  0.421937  0.851537  0.647230  0.160484  0.794109  0.379888  0.768939
#
#          28        29        30        31        32        33        34  \
# ...

# %% [markdown]
# ### 2.2 显示被压缩的文本

# %%
pd.options.display.max_rows
pd.set_option('display.max_colwidth', None)

# %%
string_x = "if the df has a lot of rows or columns, then when you try to show the df, pandas will auto detect \
the size of the displaying area and automatically hide some part of the data by replacing with"

df = pd.DataFrame({'string_x': string_x}, index = [0])

# %%
df
# Out:
#                                                                                                                                                                                            string_x
# 0  if the df has a lot of rows or columns, then when you try to show the df, pandas will auto detect the size of the displaying area and automatically hide some part of the data by replacing with

# %% [markdown]
# ## 3.数据操作类

# %% [markdown]
# ### 3.1 缺失值汇总

# %%
# Missing values
def missing_values_table(df):
        # Total missing values
        mis_val = df.isnull().sum()
        
        # Percentage of missing values
        mis_val_percent = 100 * df.isnull().sum() / len(df)
        
        # Make a table with the results
        mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
        
        # Rename the columns
        mis_val_table_ren_columns = mis_val_table.rename(
        columns = {0 : 'Missing Values', 1 : '% of Total Values'})
        
        # Sort the table by percentage of missing descending
        mis_val_table_ren_columns = mis_val_table_ren_columns[
            mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
        '% of Total Values', ascending=False).round(1)
        
        # Print some summary information
        print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n"      
            "There are " + str(mis_val_table_ren_columns.shape[0]) +
              " columns that have missing values.")
        
        # Return the dataframe with missing information
        return mis_val_table_ren_columns

# %%
city_day = pd.read_csv('/Users/didiw/Documents/study/kaggle/project/EDAstudy/input/city_day.csv')
missing_values= missing_values_table(city_day)
missing_values.style.background_gradient(cmap='Reds')
# Out:
# Your selected dataframe has 16 columns.
# There are 14 columns that have missing values.
# <style  type="text/css" >
# #T_50647_row0_col0,#T_50647_row0_col1{
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }#T_50647_row1_col0,#T_50647_row1_col1{
#             background-color:  #f24734;
#             color:  #000000;
#         }#T_50647_row2_col0{
#             background-color:  #f85f43;
#             color:  #000000;
#         }#T_50647_row2_col1{
#             background-color:  #f85d42;
#             color:  #000000;
#         }#T_50647_row3_col0,#T_50647_row3_col1{
#             background-color:  #fc9272;
#             color:  #000000;
#         }#T_50647_row4_col0,#T_50647_row4_col1{
#             background-color:  #fcc3ab;
#             color:  #000000;
#         }#T_50647_row5_col0,#T_50647_row5_col1,#T_50647_row6_col0,#T_50647_row7_col0{
#             background-color:  #fdd7c6;
#             color:  #000000;
# ...
